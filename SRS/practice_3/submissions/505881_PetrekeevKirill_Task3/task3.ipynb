# %% [markdown]
# # Task 3
#
# * Tendon
#
# R1 = 0.042
#
# R2 = 0.025
#
# a = 0.075
#
# b = 0.081
#
# c = 0.046

# %%
import mujoco
import mujoco.viewer
import time
import os

os.environ['MUJOCO_GL'] = 'egl'
# model = mujoco.MjModel.from_xml_path("model.xml")
current_dir = os.path.dirname(os.path.abspath(__file__))
model_path = os.path.join(current_dir, "mech.xml")

model = mujoco.MjModel.from_xml_path(model_path)
data = mujoco.MjData(model)

with mujoco.viewer.launch(model, data) as viewer:
    while viewer.is_running():
        mujoco.mj_step(model, data)
        viewer.sync()
        time.sleep(0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7 model = mujoco.MjModel.from_xml_path("mech.xml")
#       8 # current_dir = os.path.dirname(os.path.abspath(__file__))
#       9 # model_path = os.path.join(current_dir, "mech.xml")
# ---> 11 model = mujoco.MjModel.from_xml_path(model)
#      12 data = mujoco.MjData(model)
#      14 with mujoco.viewer.launch(model, data) as viewer:
#
# TypeError: from_xml_path(): incompatible function arguments. The following argument types are supported:
#     1. (filename: str, assets: collections.abc.Mapping[str, bytes] | None = None) -> mujoco._structs.MjModel
#
# Invoked with: <mujoco._structs.MjModel object at 0x77c7341ed9b0>
